# %% [markdown]
# ***`My Name Is Aryan choudhari`***

# %% [markdown]
# ***Dataset Name: Road casuality2022.csv***
#
# In this dataset there 19 columns which tell us about the acident casuality of 2022 from the data like['status', 'accident_index', 'accident_year', 'accident_reference',
#        'vehicle_reference', 'casualty_reference', 'casualty_class',
#        'sex_of_casualty', 'age_of_casualty', 'age_band_of_casualty',
#        'casualty_severity', 'pedestrian_location', 'pedestrian_movement',
#        'car_passenger', 'bus_or_coach_passenger',
#        'pedestrian_road_maintenance_worker', 'casualty_type',
#        'casualty_home_area_type', 'casualty_imd_decile']

# %%
import pandas as pd                # For data manipulation and analysis
import numpy as np                 # For numerical operations
import matplotlib.pyplot as plt    # For data visualization
import seaborn as sns              # For advanced data visualization
from sklearn.model_selection import train_test_split   # For splitting the data into training and testing sets
from sklearn.linear_model import LinearRegression     # For Linear Regression modeling
from sklearn.metrics import mean_squared_error        # For calculating Mean Squared Error (MSE) for evaluation

# %%
# read the file data or loading it.
df= pd.read_csv("road-casualty2022.csv")
df
# Out:
#             status accident_index  accident_year accident_reference  \
# 0      Unvalidated  2022070151244           2022          070151244
# 1      Unvalidated  2022070152668           2022          070152668
# 2      Unvalidated  2022070154696           2022          070154696
# 3      Unvalidated  2022070154696           2022          070154696
# 4      Unvalidated  2022070154696           2022          070154696
# ...            ...            ...            ...                ...
# 61347  Unvalidated  2022461156711           2022          461156711
# 61348  Unvalidated  2022461157243           2022          461157243
# 61349  Unvalidated  2022461157256           2022          461157256
# 61350  Unvalidated  2022461157316           2022          461157316
# 61351  Unvalidated  2022461159841           2022          461159841
#
#        vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# ...

# %%
df.columns
# Out:
# Index(['status', 'accident_index', 'accident_year', 'accident_reference',
#        'vehicle_reference', 'casualty_reference', 'casualty_class',
#        'sex_of_casualty', 'age_of_casualty', 'age_band_of_casualty',
#        'casualty_severity', 'pedestrian_location', 'pedestrian_movement',
#        'car_passenger', 'bus_or_coach_passenger',
#        'pedestrian_road_maintenance_worker', 'casualty_type',
#        'casualty_home_area_type', 'casualty_imd_decile', 'lsoa_of_casualty'],
#       dtype='object')

# %%
#show the top five rows of dataset
df.head(5)
# Out:
#         status accident_index  accident_year accident_reference  \
# 0  Unvalidated  2022070151244           2022          070151244
# 1  Unvalidated  2022070152668           2022          070152668
# 2  Unvalidated  2022070154696           2022          070154696
# 3  Unvalidated  2022070154696           2022          070154696
# 4  Unvalidated  2022070154696           2022          070154696
#
#    vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# 0                  2                   1               1                2
# 1                  1                   1               1                1
# 2                  1                   1               1                2
# 3                  2                   3               1                2
# 4                  3                   2               1                1
#
#    age_of_casualty  age_band_of_casualty  casualty_severity  \
# 0               46                     8                  3
# ...

# %%
#shows the last five rows of dataset
df.tail()
# Out:
#             status accident_index  accident_year accident_reference  \
# 61347  Unvalidated  2022461156711           2022          461156711
# 61348  Unvalidated  2022461157243           2022          461157243
# 61349  Unvalidated  2022461157256           2022          461157256
# 61350  Unvalidated  2022461157316           2022          461157316
# 61351  Unvalidated  2022461159841           2022          461159841
#
#        vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# 61347                  1                   1               3                2
# 61348                  1                   1               3                1
# 61349                  2                   1               1                1
# 61350                  1                   1               1                2
# 61351                  2                   1               1                1
#
#        age_of_casualty  age_band_of_casualty  casualty_severity  \
# ...

# %%
#shows random 10 rows of dataset
df.sample(10)
# Out:
#             status accident_index  accident_year accident_reference  \
# 46432  Unvalidated  2022430138687           2022          430138687
# 33362  Unvalidated  2022122200514           2022          122200514
# 53208  Unvalidated  2022311159229           2022          311159229
# 44360  Unvalidated  2022010363149           2022          010363149
# 31611  Unvalidated  2022010383878           2022          010383878
# 52361  Unvalidated  2022201185053           2022          201185053
# 16657  Unvalidated  2022351161338           2022          351161338
# 50386  Unvalidated  2022010363283           2022          010363283
# 56036  Unvalidated  2022471156637           2022          471156637
# 57112  Unvalidated  2022061173398           2022          061173398
#
#        vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# 46432                  2                   1               1                1
# ...

# %%
#Droping the lsoa of casuality
df.drop("lsoa_of_casualty",axis=1,inplace=True)

# %%
#it tell us there is 61352 rows and 19 column
df.shape
# Out:
# (61352, 19)

# %%
# Here we get all information of datasets like range index ,column ,non null count,data type.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61352 entries, 0 to 61351
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   status                              61352 non-null  object
#  1   accident_index                      61352 non-null  object
#  2   accident_year                       61352 non-null  int64
#  3   accident_reference                  61352 non-null  object
#  4   vehicle_reference                   61352 non-null  int64
#  5   casualty_reference                  61352 non-null  int64
#  6   casualty_class                      61352 non-null  int64
#  7   sex_of_casualty                     61352 non-null  int64
#  8   age_of_casualty                     61352 non-null  int64
#  9   age_band_of_casualty                61352 non-null  int64
#  10  casualty_severity                   61352 non-null  int64
# ...

# %%
df.count() #count the data in each columns
# Out:
# status                                61352
# accident_index                        61352
# accident_year                         61352
# accident_reference                    61352
# vehicle_reference                     61352
# casualty_reference                    61352
# casualty_class                        61352
# sex_of_casualty                       61352
# age_of_casualty                       61352
# age_band_of_casualty                  61352
# casualty_severity                     61352
# pedestrian_location                   61352
# pedestrian_movement                   61352
# car_passenger                         61352
# bus_or_coach_passenger                61352
# pedestrian_road_maintenance_worker    61352
# casualty_type                         61352
# casualty_home_area_type               61352
# casualty_imd_decile                   61352
# dtype: int64

# %%
print(df.isnull().sum()) #check the sum of null values of columns
# Out:
# status                                0
# accident_index                        0
# accident_year                         0
# accident_reference                    0
# vehicle_reference                     0
# casualty_reference                    0
# casualty_class                        0
# sex_of_casualty                       0
# age_of_casualty                       0
# age_band_of_casualty                  0
# casualty_severity                     0
# pedestrian_location                   0
# pedestrian_movement                   0
# car_passenger                         0
# bus_or_coach_passenger                0
# pedestrian_road_maintenance_worker    0
# casualty_type                         0
# casualty_home_area_type               0
# casualty_imd_decile                   0
# dtype: int64

# %%
df=df.dropna()#droping the null values of the columns

# %%
df.count()
# Out:
# status                                61352
# accident_index                        61352
# accident_year                         61352
# accident_reference                    61352
# vehicle_reference                     61352
# casualty_reference                    61352
# casualty_class                        61352
# sex_of_casualty                       61352
# age_of_casualty                       61352
# age_band_of_casualty                  61352
# casualty_severity                     61352
# pedestrian_location                   61352
# pedestrian_movement                   61352
# car_passenger                         61352
# bus_or_coach_passenger                61352
# pedestrian_road_maintenance_worker    61352
# casualty_type                         61352
# casualty_home_area_type               61352
# casualty_imd_decile                   61352
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# status                                0
# accident_index                        0
# accident_year                         0
# accident_reference                    0
# vehicle_reference                     0
# casualty_reference                    0
# casualty_class                        0
# sex_of_casualty                       0
# age_of_casualty                       0
# age_band_of_casualty                  0
# casualty_severity                     0
# pedestrian_location                   0
# pedestrian_movement                   0
# car_passenger                         0
# bus_or_coach_passenger                0
# pedestrian_road_maintenance_worker    0
# casualty_type                         0
# casualty_home_area_type               0
# casualty_imd_decile                   0
# dtype: int64

# %%
# Here we get mean,mode,median and 50%,75%,max,min rating of the persons
print(df.describe())
# Out:
#        accident_year  vehicle_reference  casualty_reference  casualty_class  \
# count        61352.0       61352.000000        61352.000000    61352.000000
# mean          2022.0           1.450368            1.333779        1.482299
# std              0.0           1.109855            0.981507        0.735614
# min           2022.0           1.000000            1.000000        1.000000
# 25%           2022.0           1.000000            1.000000        1.000000
# 50%           2022.0           1.000000            1.000000        1.000000
# 75%           2022.0           2.000000            1.000000        2.000000
# max           2022.0         227.000000          148.000000        3.000000
#
#        sex_of_casualty  age_of_casualty  age_band_of_casualty  \
# count     61352.000000     61352.000000          61352.000000
# mean          1.368790        36.670312              6.288157
# std           0.534536        19.574357              2.463082
# ...

# %%
# Creates a box plot of the age band casuality
sns.boxplot(x=df['age_band_of_casualty'])
# Out:
# <Axes: xlabel='age_band_of_casualty'>

# %%
# Detect and handle outliers using IQR method or Z-score method
# For example, using IQR method:
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# accident_year                          0.0
# vehicle_reference                      1.0
# casualty_reference                     0.0
# casualty_class                         1.0
# sex_of_casualty                        1.0
# age_of_casualty                       28.0
# age_band_of_casualty                   3.0
# casualty_severity                      0.0
# pedestrian_location                    0.0
# pedestrian_movement                    0.0
# car_passenger                          0.0
# bus_or_coach_passenger                 0.0
# pedestrian_road_maintenance_worker     0.0
# casualty_type                          8.0
# casualty_home_area_type                0.0
# casualty_imd_decile                    5.0
# dtype: float64
# <ipython-input-166-69c18379539e>:3: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# <ipython-input-167-9479ebe7591b>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# outlier is removed
sns.boxplot(x=df['age_band_of_casualty'])
# Out:
# <Axes: xlabel='age_band_of_casualty'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# accident_year                          0.0
# vehicle_reference                      1.0
# casualty_reference                     0.0
# casualty_class                         0.0
# sex_of_casualty                        1.0
# age_of_casualty                       22.0
# age_band_of_casualty                   2.0
# casualty_severity                      0.0
# pedestrian_location                    0.0
# pedestrian_movement                    0.0
# car_passenger                          0.0
# bus_or_coach_passenger                 0.0
# pedestrian_road_maintenance_worker     0.0
# casualty_type                          6.0
# casualty_home_area_type                0.0
# casualty_imd_decile                    5.0
# dtype: float64
# <ipython-input-169-d7397e803310>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# <ipython-input-170-9479ebe7591b>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# outlier is removed
sns.boxplot(x=df['age_band_of_casualty'])
# Out:
# <Axes: xlabel='age_band_of_casualty'>

# %%
# Visualize  the dataset using pair plots or scatter matrix
#visualize all the columns
sns.pairplot(df)
plt.show()

# %%
# get the count of each unique value in the 'vehicle refrence' column
df['vehicle_reference'].value_counts()
# Out:
# 1    10945
# 2     8213
# 3      259
# Name: vehicle_reference, dtype: int64

# %%
# get an array of unique values in the 'vehicle refrence' column
df['vehicle_reference'].unique()
# Out:
# array([2, 1, 3])

# %%
# get the number of unique values in the 'vehicle refrence' column
df['vehicle_reference'].nunique()
# Out:
# 3

# %%
# create a bar plot of the count of each unique value in the 'vehicle refrence' column
df['vehicle_reference'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
# Visualize correlation heatmap
sns.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# <ipython-input-177-c108b1195aa0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %%
# show the Datatype of price in casuality severity column
df["casualty_severity"].dtype
# Out:
# dtype('int64')

# %%
# Plot a histogram of the 'casuality severity' column with KDE (Kernel Density Estimation)
# Display the histogram
sns.histplot(df['casualty_severity'], kde=True)
plt.show()

# %%
sns.histplot(df['car_passenger'], kde=True)
plt.show()

# %%
sns.histplot(df['bus_or_coach_passenger'], kde=True)
plt.show()

# %%
#selects all rows and all columns except the last column from the DataFrame and print table
x=df.iloc[::,:-1 ]
x.head()
# Out:
#          status accident_index  accident_year accident_reference  \
# 0   Unvalidated  2022070151244           2022          070151244
# 1   Unvalidated  2022070152668           2022          070152668
# 2   Unvalidated  2022070154696           2022          070154696
# 9   Unvalidated  2022070155656           2022          070155656
# 12  Unvalidated  2022070171945           2022          070171945
#
#     vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# 0                   2                   1               1                2
# 1                   1                   1               1                1
# 2                   1                   1               1                2
# 9                   1                   1               1                1
# 12                  1                   1               1                1
#
#     age_of_casualty  age_band_of_casualty  casualty_severity  \
# ...

# %%
y=df.iloc[:,-1]
y.head()
# Out:
# 0      9
# 1      2
# 2     10
# 9      8
# 12     8
# Name: casualty_imd_decile, dtype: int64

# %%
df
# Out:
#             status accident_index  accident_year accident_reference  \
# 0      Unvalidated  2022070151244           2022          070151244
# 1      Unvalidated  2022070152668           2022          070152668
# 2      Unvalidated  2022070154696           2022          070154696
# 9      Unvalidated  2022070155656           2022          070155656
# 12     Unvalidated  2022070171945           2022          070171945
# ...            ...            ...            ...                ...
# 61340  Unvalidated  2022461155961           2022          461155961
# 61345  Unvalidated  2022461156462           2022          461156462
# 61349  Unvalidated  2022461157256           2022          461157256
# 61350  Unvalidated  2022461157316           2022          461157316
# 61351  Unvalidated  2022461159841           2022          461159841
#
#        vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# ...

# %%
#calculates the skewness of the values
df.skew(axis = 0, skipna = True)
# Out:
# <ipython-input-185-8eb3bdbb9dea>:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew(axis = 0, skipna = True)
# accident_year                         0.000000
# vehicle_reference                     0.480479
# casualty_reference                    0.000000
# casualty_class                        0.000000
# sex_of_casualty                       0.712412
# age_of_casualty                       0.640820
# age_band_of_casualty                  0.237536
# casualty_severity                     0.000000
# pedestrian_location                   0.000000
# pedestrian_movement                   0.000000
# car_passenger                         0.000000
# bus_or_coach_passenger                0.000000
# pedestrian_road_maintenance_worker    0.000000
# ...

# %% [markdown]
# ***Encoder the code***

# %%
#technique that converts categorical data into numerical data#
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for column in df.columns:
    if df[column].dtype == "object":
        df[column] = le.fit_transform(df[column])

# %% [markdown]
# **Linear Regression **

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
#imports the train_test_split function from the sklearn.model_selection module
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df, df["status"], test_size=0.3, random_state=42)

# %%
#Create and train the Linear Regression model
model = LinearRegression()
#fits the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions using the test data
y_pred = model.predict(X_test)

# %%
#print classification report  on model
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5826
#
#     accuracy                           1.00      5826
#    macro avg       1.00      1.00      1.00      5826
# weighted avg       1.00      1.00      1.00      5826

# %%
#accuracy of a model or datafarme
model.score(X_train,y_train)
# Out:
# 1.0
